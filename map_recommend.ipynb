# %%
import folium
import pandas as pd
df = pd.read_csv('restaurant_list.csv', encoding='utf-8')
df.columns= ['id',
             'name',
             'cate',
             'dong',
             'lat',
             'lon',
             'score',
             'review',
             ]

map = folium.Map(location=[37.561142, 126.986133], # 명동역
                 tiles="CartoDB positron",
                 zoom_start=14)

# %%
from folium.plugins import MarkerCluster
from folium import Marker

# 밀집되어 있을 시에 보기 불편함을 해소해주기 위해 주변지역을 묶어서 대략적인 개수 분포 보기
mc = MarkerCluster()

# 평점별 다른 색으로 마커 표시
def color_select(row):
    score = float(row.score)
    if score >= 4.7:
        return 'blue'
    elif score >= 4.3:
        return 'green'
    else:
        return 'beige'
# 카테고리별 다른 아이콘으로 마커 표시
def cate_select(row):
    if row.cate.strip() in ['한식', '일식', '중식']:
        return 'bowl-food'
    elif row.cate == '양식':
        return 'utensils'
    else:
        return 'mug-saucer'

for i, r in df.iterrows():
    place_id = str(r['id'])
    name = str(r['name'])
    mc.add_child(
        Marker(location = [r['lat'], r['lon']],
               tooltip = r['name'],
               popup=folium.Popup(f'<a href="https://place.map.kakao.com/{place_id}">{name}[상세 정보 보기]</a>',
                                  max_width=1000),
               icon=folium.Icon(color = color_select(r),icon=cate_select(r), prefix='fa')
              )
    )

map.add_child(mc)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_099469768484b823539491c6f778e2c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_099469768484b823539491c6f778e2c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_099469768484b823539491c6f778e2c0 = L.map(
#                 &quot;map_099469768484b823539491c6f778e2c0&quot;,
#                 {
#                     center: [37.561142, 126.986133],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f4948c0e6ed9d68fc4ff41f5a190d85 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_099469768484b823539491c6f778e2c0);
#
#
#             var marker_cluster_8bada50aa14d90476fd6ce8dec3a299d = L.markerClusterGroup(
#                 {}
#             );
#             map_099469768484b823539491c6f778e2c0.addLayer(marker_cluster_8bada50aa14d90476fd6ce8dec3a299d);
#
#
#             var marker_98ede122d6334500c61abaed6800efdb = L.marker(
#                 [37.562711, 126.983746],
#                 {}
#             ).addTo(marker_cluster_8bada50aa14d90476fd6ce8dec3a299d);
#
#
#             var icon_00f1d875463945eb71eb4d35e6190813 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;mug-saucer&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_98ede122d6334500c61abaed6800efdb.setIcon(icon_00f1d875463945eb71eb4d35e6190813);
#
#
#         var popup_9accf9ff76a64cfeeae099625b038ae6 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_035a586d43a5b60bc1d6b052554cdac2 = $(`&lt;div id=&quot;html_035a586d43a5b60bc1d6b052554cdac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://place.map.kakao.com/1292414361&quot;&gt; 카페 드 파리[상세 정보 보기]&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_9accf9ff76a64cfeeae099625b038ae6.setContent(html_035a586d43a5b60bc1d6b052554cdac2);
#
#
#
#         marker_98ede122d6334500c61abaed6800efdb.bindPopup(popup_9accf9ff76a64cfeeae099625b038ae6)
#         ;
#
#
#
#
#             marker_98ede122d6334500c61abaed6800efdb.bindTooltip(
#                 `&lt;div&gt;
#                       카페 드 파리
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6b8c4c95702dd38263f0c675f11bb751 = L.marker(
#                 [37.564577, 126.986213],
#                 {}
#             ).addTo(marker_cluster_8bada50aa14d90476fd6ce8dec3a299d);
#
#
#             var icon_e57fae5abfb31459e7b4bc873a1b3c5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;mug-saucer&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6b8c4c95702dd38263f0c675f11bb751.setIcon(icon_e57fae5abfb31459e7b4bc873a1b3c5c);
#
#
#         var popup_7147c7f29bc3d617cf96225200560bc1 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_b0898f8691b024e6c9bcc1bfb6cf2ace = $(`&lt;div id=&quot;html_b0898f8691b024e6c9bcc1bfb6cf2ace&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://place.map.kakao.com/1798095400&quot;&gt; 몰또이탈리안에소프레소바[상세 정보 보기]&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_7147c7f29bc3d617cf96225200560bc1.setContent(html_b0898f8691b024e6c9bcc1bfb6cf2ace);
#
#
#
#         marker_6b8c4c95702dd38263f0c675f11bb751.bindPopup(popup_7147c7f29bc3d617cf96225200560bc1)
#         ;
#
#
#
#
#             marker_6b8c4c95702dd38263f0c675f11bb751.bindTooltip(
#                 `&lt;div&gt;
#                       몰또이탈리안에소프레소바
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4d28d9bb735c12eadba12625981d7770 = L.marker(
#                 [37.56324, 126.987005],
#                 {}

# %%
from folium import plugins

# 유저 실시간 위치 파악
plugins.LocateControl().add_to(map)
map.save('maptest.html')
